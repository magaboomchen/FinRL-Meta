# %% [markdown]
# <a href="https://colab.research.google.com/github/AI4Finance-Foundation/FinRL/blob/master/Stock_NeurIPS2018.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch: Multiple Stock Trading
#
# * **Pytorch Version**

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Task Description](#0)
# * [2. Install Python packages](#1)
#     * [2.1. Install Packages](#1.1)
#     * [2.2. A List of Python Packages](#1.2)
#     * [2.3. Import Packages](#1.3)
#     * [2.4. Create Folders](#1.4)
# * [3. Download and Preprocess Data](#2)
# * [4. Preprocess Data](#3)
#     * [4.1. Technical Indicators](#3.1)
#     * [4.2. Perform Feature Engineering](#3.2)
# * [5. Build Market Environment in OpenAI Gym-style](#4)
#     * [5.1. Data Split](#4.1)
#     * [5.3. Environment for Training](#4.2)
# * [6. Train DRL Agents](#5)
# * [7. Backtesting Performance](#6)
#     * [7.1. BackTestStats](#6.1)
#     * [7.2. BackTestPlot](#6.2)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Task Discription

# %% [markdown]
# We train a DRL agent for stock trading. This task is modeled as a Markov Decision Process (MDP), and the objective function is maximizing (expected) cumulative return.
#
# We specify the state-action-reward as follows:
#
# * **State s**: The state space represents an agent's perception of the market environment. Just like a human trader analyzing various information, here our agent passively observes many features and learns by interacting with the market environment (usually by replaying historical data).
#
# * **Action a**: The action space includes allowed actions that an agent can take at each state. For example, a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying. When an action operates multiple shares, a ∈{−k, ..., −1, 0, 1, ..., k}, e.g.. "Buy
# 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * **Reward function r(s, a, s′)**: Reward is an incentive for an agent to learn a better policy. For example, it can be the change of the portfolio value when taking a at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio values at state s′ and s, respectively
#
#
# **Market environment**: 30 consituent stocks of Dow Jones Industrial Average (DJIA) index. Accessed at the starting date of the testing period.
#
#
# The data for this case study is obtained from Yahoo Finance API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# <a id='1'></a>
# # Part 2. Install Python Packages

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Install packages

# %%
## install finrl library
#!pip install git+https://github.com/AI4Finance-Foundation/FinRL.git

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. A list of Python packages
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Import Packages

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime

# %matplotlib inline
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import data_split
from meta.local.finrl.prepocessors import FeatureEngineerPrivate
from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent
from finrl.meta.data_processor import DataProcessor

from finrl.plot import backtest_stats, backtest_plot, get_daily_return
from pprint import pprint

from meta.local.yfinance.plot import get_baseline

import sys
sys.path.append("../FinRL")

import itertools

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %%
from finrl import config
from finrl import config_tickers
import os
if not os.path.exists("./" + config.DATA_SAVE_DIR):
    os.makedirs("./" + config.DATA_SAVE_DIR)
if not os.path.exists("./" + config.TRAINED_MODEL_DIR):
    os.makedirs("./" + config.TRAINED_MODEL_DIR)
if not os.path.exists("./" + config.TENSORBOARD_LOG_DIR):
    os.makedirs("./" + config.TENSORBOARD_LOG_DIR)
if not os.path.exists("./" + config.RESULTS_DIR):
    os.makedirs("./" + config.RESULTS_DIR)

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance provides stock data, financial news, financial reports, etc. Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** in FinRL-Meta to fetch data via Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %% [markdown]
# -----
# class YahooDownloader:
#     Retrieving daily stock data from
#     Yahoo Finance API
#
#     Attributes
#     ----------
#         start_date : str
#             start date of the data (modified from config.py)
#         end_date : str
#             end date of the data (modified from config.py)
#         ticker_list : list
#             a list of stock tickers (modified from config.py)
#
#     Methods
#     -------
#     fetch_data()

# %%
# from config.py, TRAIN_START_DATE is a string
config.TRAIN_START_DATE
# Out:
# '2014-01-06'

# %%
# from config.py, TRAIN_END_DATE is a string
config.TRAIN_END_DATE
# Out:
# '2020-07-31'

# %%
df = YahooDownloader(start_date = '2009-01-01',
                     end_date = '2021-10-31',
                     ticker_list = config_tickers.DOW_30_TICKER).fetch_data(proxy="127.0.0.1:1080")
# Out:
# [*********************100%***********************]  1 of 1 completed
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/yahoodownloader.py:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/yahoodownloader.py:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/yahoodownloader.py:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/yahoodownloader.py:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/yahoodownloader.py:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/yahoodownloader.py:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/yahoodownloader.py:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/yahoodownloader.py:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/yahoodownloader.py:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/yahoodownloader.py:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/yahoodownloader.py:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/yahoodownloader.py:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/yahoodownloader.py:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/yahoodownloader.py:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/yahoodownloader.py:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/yahoodownloader.py:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/yahoodownloader.py:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/yahoodownloader.py:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/yahoodownloader.py:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/yahoodownloader.py:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/yahoodownloader.py:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/yahoodownloader.py:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/yahoodownloader.py:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/yahoodownloader.py:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/yahoodownloader.py:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/yahoodownloader.py:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/yahoodownloader.py:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/yahoodownloader.py:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/yahoodownloader.py:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/yahoodownloader.py:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# Shape of DataFrame:  (94360, 8)

# %%
print(config_tickers.DOW_30_TICKER)
# Out:
# ['AXP', 'AMGN', 'AAPL', 'BA', 'CAT', 'CSCO', 'CVX', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ', 'KO', 'JPM', 'MCD', 'MMM', 'MRK', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'CRM', 'VZ', 'V', 'WBA', 'WMT', 'DIS', 'DOW']

# %%
df.shape
# Out:
# (94360, 8)

# %%
df.sort_values(['date','tic'],ignore_index=True).head()
# Out:
#          date       open       high        low      close     volume   tic  \
# 0  2008-12-31   3.070357   3.133571   3.047857   2.602662  607541200  AAPL
# 1  2008-12-31  57.110001  58.220001  57.060001  43.587841    6287200  AMGN
# 2  2008-12-31  17.969999  18.750000  17.910000  14.852880    9625600   AXP
# 3  2008-12-31  41.590000  43.049999  41.500000  32.005871    5443100    BA
# 4  2008-12-31  43.700001  45.099998  43.700001  30.416965    6277400   CAT
#
#    day
# 0    2
# 1    2
# 2    2
# 3    2
# 4    2

# %% [markdown]
# # Part 4: Preprocess Data
# We need to check for missing data and do feature engineering to convert the data point into a state.
# * **Adding technical indicators**. In practical trading, various information needs to be taken into account, such as historical prices, current holding shares, technical indicators, etc. Here, we demonstrate two trend-following technical indicators: MACD and RSI.
# * **Adding turbulence index**. Risk-aversion reflects whether an investor prefers to protect the capital. It also influences one's trading strategy when facing different market volatility level. To control the risk in a worst-case scenario, such as financial crisis of 2007–2008, FinRL employs the turbulence index that measures extreme fluctuation of asset price.

# %%
import importlib
import meta
importlib.reload(meta.local.finrl.prepocessors)
from meta.local.finrl.prepocessors import FeatureEngineerPrivate

fe = FeatureEngineerPrivate(
                    use_technical_indicator=True,
                    tech_indicator_list = config.INDICATORS,
                    use_vix=True,
                    use_turbulence=True,
                    user_defined_feature = False)

processed = fe.preprocess_data(df)
# Out:
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# Successfully added technical indicators
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (3231, 8)
# Successfully added vix
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/yahoodownloader.py:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# Successfully added turbulence index

# %%
list_ticker = processed["tic"].unique().tolist()
list_date = list(pd.date_range(processed['date'].min(),processed['date'].max()).astype(str))
combination = list(itertools.product(list_date,list_ticker))

processed_full = pd.DataFrame(combination,columns=["date","tic"]).merge(processed,on=["date","tic"],how="left")
processed_full = processed_full[processed_full['date'].isin(processed['date'])]
processed_full = processed_full.sort_values(['date','tic'])

processed_full = processed_full.fillna(0)

# %%
processed_full.sort_values(['date','tic'],ignore_index=True).head(10)
# Out:
#          date   tic       open       high        low      close       volume  \
# 0  2008-12-31  AAPL   3.070357   3.133571   3.047857   2.602662  607541200.0
# 1  2008-12-31  AMGN  57.110001  58.220001  57.060001  43.587841    6287200.0
# 2  2008-12-31   AXP  17.969999  18.750000  17.910000  14.852880    9625600.0
# 3  2008-12-31    BA  41.590000  43.049999  41.500000  32.005871    5443100.0
# 4  2008-12-31   CAT  43.700001  45.099998  43.700001  30.416965    6277400.0
# 5  2008-12-31   CRM   7.712500   8.130000   7.707500   8.002500    5367600.0
# 6  2008-12-31  CSCO  16.180000  16.549999  16.120001  11.575118   37513700.0
# 7  2008-12-31   CVX  72.900002  74.629997  72.900002  42.924419    9964300.0
# 8  2008-12-31   DIS  22.570000  22.950001  22.520000  19.538349    9012100.0
# 9  2008-12-31    GS  82.239998  86.150002  81.120003  68.287239   14894100.0
#
#    day  macd  boll_ub   boll_lb  rsi_30     cci_30  dx_30  close_30_sma  \
# 0  2.0   0.0  2.91787  2.452122   100.0  66.666667  100.0      2.602662
# 1  2.0   0.0  2.91787  2.452122   100.0  66.666667  100.0     43.587841
# 2  2.0   0.0  2.91787  2.452122   100.0  66.666667  100.0     14.852880
# 3  2.0   0.0  2.91787  2.452122   100.0  66.666667  100.0     32.005871
# 4  2.0   0.0  2.91787  2.452122   100.0  66.666667  100.0     30.416965
# 5  2.0   0.0  2.91787  2.452122   100.0  66.666667  100.0      8.002500
# 6  2.0   0.0  2.91787  2.452122   100.0  66.666667  100.0     11.575118
# 7  2.0   0.0  2.91787  2.452122   100.0  66.666667  100.0     42.924419
# 8  2.0   0.0  2.91787  2.452122   100.0  66.666667  100.0     19.538349
# 9  2.0   0.0  2.91787  2.452122   100.0  66.666667  100.0     68.287239
#
#    close_60_sma   vix  turbulence
# 0      2.602662  40.0         0.0
# 1     43.587841  40.0         0.0
# 2     14.852880  40.0         0.0
# 3     32.005871  40.0         0.0
# 4     30.416965  40.0         0.0
# 5      8.002500  40.0         0.0
# 6     11.575118  40.0         0.0
# 7     42.924419  40.0         0.0
# 8     19.538349  40.0         0.0
# 9     68.287239  40.0         0.0

# %% [markdown]
# <a id='4'></a>
# # Part 5. Build A Market Environment in OpenAI Gym-style
# The training process involves observing stock price change, taking an action and reward's calculation. By interacting with the market environment, the agent will eventually derive a trading strategy that may maximize (expected) rewards.
#
# Our market environment, based on OpenAI Gym, simulates stock markets with historical market data.

# %% [markdown]
# ## Data Split
# We split the data into training set and testing set as follows:
#
# Training data period: 2009-01-01 to 2020-07-01
#
# Trading data period: 2020-07-01 to 2021-10-31

# %%
train = data_split(processed_full, '2009-01-01','2020-07-01')
trade = data_split(processed_full, '2020-07-01','2021-10-31')
print(len(train))
print(len(trade))
# Out:
# 83897
# 9744

# %%
train.tail()
# Out:
#             date  tic        open        high         low       close  \
# 2892  2020-06-30  UNH  288.570007  296.450012  287.660004  285.857208
# 2892  2020-06-30    V  191.490005  193.750000  190.160004  190.400009
# 2892  2020-06-30   VZ   54.919998   55.290001   54.360001   48.926277
# 2892  2020-06-30  WBA   42.119999   42.580002   41.759998   38.577274
# 2892  2020-06-30  WMT  119.220001  120.129997  118.540001  115.618225
#
#           volume  day      macd     boll_ub     boll_lb     rsi_30     cci_30  \
# 2892   2932900.0  1.0 -0.019351  301.898602  269.441883  52.413041 -25.890848
# 2892   9040100.0  1.0  1.046931  198.399123  184.714225  53.021037 -51.567816
# 2892  17414800.0  1.0 -0.424525   52.365982   47.326287  48.097053 -51.128314
# 2892   4782100.0  1.0 -0.083000   42.108879   36.058570  48.830179 -14.542157
# 2892   6836400.0  1.0 -0.882725  118.955679  113.018228  48.159676 -69.952671
#
#          dx_30  close_30_sma  close_60_sma    vix  turbulence
# 2892  1.846804    286.099490    279.127067  30.43   12.918787
# 2892  2.013358    191.146477    181.356465  30.43   12.918787
# 2892  8.508886     49.543359     49.982885  30.43   12.918787
# 2892  1.500723     38.675565     38.477854  30.43   12.918787
# 2892  3.847271    117.276855    119.204111  30.43   12.918787

# %%
trade.head()
# Out:
#          date   tic        open        high         low       close  \
# 0  2020-07-01  AAPL   91.279999   91.839996   90.977501   89.779884
# 0  2020-07-01  AMGN  235.520004  256.230011  232.580002  238.313583
# 0  2020-07-01   AXP   95.250000   96.959999   93.639999   91.743042
# 0  2020-07-01    BA  185.880005  190.610001  180.039993  180.320007
# 0  2020-07-01   CAT  129.380005  129.399994  125.879997  119.817116
#
#         volume  day      macd     boll_ub     boll_lb     rsi_30      cci_30  \
# 0  110737200.0  2.0  3.010421   92.570729   80.068739  62.807132  107.494001
# 0    6575800.0  2.0  3.608529  230.616477  198.678622  61.279640  271.208771
# 0    3301000.0  2.0 -0.387712  110.012243   87.432131  48.504815  -66.321052
# 0   49036700.0  2.0  5.443193  220.721139  160.932863  50.925771   24.220608
# 0    2807800.0  2.0  1.263827  129.720779  112.569081  52.865423   35.633550
#
#        dx_30  close_30_sma  close_60_sma        vix  turbulence
# 0  29.730532     83.817342     77.609740  28.620001    53.06817
# 0  46.806139    213.212112    214.276892  28.620001    53.06817
# 0   3.142448     96.882071     90.357376  28.620001    53.06817
# 0  15.932920    176.472335    155.614168  28.620001    53.06817
# 0  14.457404    118.586880    112.860600  28.620001    53.06817

# %%
config.INDICATORS
# Out:
# ['macd',
#  'boll_ub',
#  'boll_lb',
#  'rsi_30',
#  'cci_30',
#  'dx_30',
#  'close_30_sma',
#  'close_60_sma']

# %%
stock_dimension = len(train.tic.unique())
state_space = 1 + 2*stock_dimension + len(config.INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 29, State Space: 291

# %%
buy_cost_list = sell_cost_list = [0.001] * stock_dimension
num_stock_shares = [0] * stock_dimension

env_kwargs = {
    "hmax": 100,
    "initial_amount": 1000000,
    "num_stock_shares": num_stock_shares,
    "buy_cost_pct": buy_cost_list,
    "sell_cost_pct": sell_cost_list,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": config.INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": 1e-4
}


e_train_gym = StockTradingEnv(df = train, **env_kwargs)

# %% [markdown]
# ## Environment for Training

# %%
env_train, _ = e_train_gym.get_sb_env()
print(type(env_train))
# Out:
# <class 'stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv'>

# %% [markdown]
# <a id='5'></a>
# # Part 6: Train DRL Agents
# * The DRL algorithms are from **Stable Baselines 3**. Users are also encouraged to try **ElegantRL** and **Ray RLlib**.
# * FinRL includes fine-tuned standard DRL algorithms, such as DQN, DDPG, Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.

# %%
agent = DRLAgent(env = env_train)

# %% [markdown]
# ### Agent Training: 5 algorithms (A2C, DDPG, PPO, TD3, SAC)

# %% [markdown]
# ### Agent 1: A2C

# %%
agent = DRLAgent(env = env_train)
model_a2c = agent.get_model("a2c")
# Out:
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.0007}
# Using cpu device

# %%
trained_a2c = agent.train_model(model=model_a2c, 
                             tb_log_name='a2c',
                             total_timesteps=50000)
# Out:
# --------------------------------------
# | time/                 |            |
# |    fps                | 92         |
# |    iterations         | 100        |
# |    time_elapsed       | 5          |
# |    total_timesteps    | 500        |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | -3.29      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 99         |
# |    policy_loss        | -0.82      |
# |    reward             | 0.21619649 |
# |    std                | 1          |
# |    value_loss         | 0.527      |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 95         |
# |    iterations         | 200        |
# |    time_elapsed       | 10         |
# |    total_timesteps    | 1000       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | -0.407     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 199        |
# |    policy_loss        | -6.01      |
# |    reward             | -1.6791053 |
# |    std                | 1          |
# |    value_loss         | 1.1        |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 98        |
# |    iterations         | 300       |
# |    time_elapsed       | 15        |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 299       |
# |    policy_loss        | -240      |
# |    reward             | 5.253484  |
# |    std                | 1         |
# |    value_loss         | 37.9      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 94          |
# |    iterations         | 400         |
# |    time_elapsed       | 21          |
# |    total_timesteps    | 2000        |
# | train/                |             |
# |    entropy_loss       | -41.1       |
# |    explained_variance | 0.0939      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 399         |
# |    policy_loss        | 243         |
# |    reward             | -0.73192465 |
# |    std                | 0.999       |
# |    value_loss         | 44          |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 97         |
# |    iterations         | 500        |
# |    time_elapsed       | 25         |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | 0.00269    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 499        |
# |    policy_loss        | 631        |
# |    reward             | -15.570851 |
# |    std                | 0.999      |
# |    value_loss         | 319        |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 98          |
# |    iterations         | 600         |
# |    time_elapsed       | 30          |
# |    total_timesteps    | 3000        |
# | train/                |             |
# |    entropy_loss       | -41.1       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 599         |
# |    policy_loss        | 85.3        |
# |    reward             | -0.03590378 |
# |    std                | 0.997       |
# |    value_loss         | 5.11        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 99         |
# |    iterations         | 700        |
# |    time_elapsed       | 35         |
# |    total_timesteps    | 3500       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | 1.91e-06   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 699        |
# |    policy_loss        | -59.9      |
# |    reward             | -3.1836572 |
# |    std                | 0.999      |
# |    value_loss         | 3.23       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 99         |
# |    iterations         | 800        |
# |    time_elapsed       | 40         |
# |    total_timesteps    | 4000       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | -0.000344  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 799        |
# |    policy_loss        | -33.3      |
# |    reward             | -3.4896984 |
# |    std                | 1          |
# |    value_loss         | 1.28       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 100        |
# |    iterations         | 900        |
# |    time_elapsed       | 44         |
# |    total_timesteps    | 4500       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 899        |
# |    policy_loss        | 58.9       |
# |    reward             | -0.9359636 |
# |    std                | 1          |
# |    value_loss         | 2.96       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 101       |
# |    iterations         | 1000      |
# |    time_elapsed       | 49        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | -4.17     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 999       |
# |    policy_loss        | -59.6     |
# |    reward             | -2.872446 |
# |    std                | 1         |
# |    value_loss         | 2.04      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 101       |
# |    iterations         | 1100      |
# |    time_elapsed       | 53        |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1099      |
# |    policy_loss        | -239      |
# |    reward             | 1.6688808 |
# |    std                | 1         |
# |    value_loss         | 33.9      |
# -------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 102          |
# |    iterations         | 1200         |
# |    time_elapsed       | 58           |
# |    total_timesteps    | 6000         |
# | train/                |              |
# |    entropy_loss       | -41.3        |
# |    explained_variance | -0.299       |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1199         |
# |    policy_loss        | -79.6        |
# |    reward             | -0.014538003 |
# |    std                | 1.01         |
# |    value_loss         | 5.01         |
# ----------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 103       |
# |    iterations         | 1300      |
# |    time_elapsed       | 63        |
# |    total_timesteps    | 6500      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1299      |
# |    policy_loss        | 51.1      |
# |    reward             | -4.450626 |
# |    std                | 1.01      |
# |    value_loss         | 6.55      |
# -------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 103          |
# |    iterations         | 1400         |
# |    time_elapsed       | 67           |
# |    total_timesteps    | 7000         |
# | train/                |              |
# |    entropy_loss       | -41.4        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1399         |
# |    policy_loss        | 109          |
# |    reward             | -0.012608459 |
# |    std                | 1.01         |
# |    value_loss         | 9.27         |
# ----------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 102      |
# |    iterations         | 1500     |
# |    time_elapsed       | 72       |
# |    total_timesteps    | 7500     |
# | train/                |          |
# |    entropy_loss       | -41.4    |
# |    explained_variance | 0.0275   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | 47.5     |
# |    reward             | 7.285794 |
# |    std                | 1.01     |
# |    value_loss         | 1.77     |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 103        |
# |    iterations         | 1600       |
# |    time_elapsed       | 77         |
# |    total_timesteps    | 8000       |
# | train/                |            |
# |    entropy_loss       | -41.4      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1599       |
# |    policy_loss        | 68.4       |
# |    reward             | 0.36199906 |
# |    std                | 1.01       |
# |    value_loss         | 3.63       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 103      |
# |    iterations         | 1700     |
# |    time_elapsed       | 82       |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -41.5    |
# |    explained_variance | -0.202   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | -208     |
# |    reward             | 5.763276 |
# |    std                | 1.01     |
# |    value_loss         | 36.6     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 103       |
# |    iterations         | 1800      |
# |    time_elapsed       | 87        |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -41.5     |
# |    explained_variance | -1.24     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1799      |
# |    policy_loss        | 2.94      |
# |    reward             | 1.7151525 |
# |    std                | 1.01      |
# |    value_loss         | 0.357     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 103       |
# |    iterations         | 1900      |
# |    time_elapsed       | 92        |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -41.5     |
# |    explained_variance | -0.149    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1899      |
# |    policy_loss        | -15.8     |
# |    reward             | 0.5356301 |
# |    std                | 1.01      |
# |    value_loss         | 0.89      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 103        |
# |    iterations         | 2000       |
# |    time_elapsed       | 96         |
# |    total_timesteps    | 10000      |
# | train/                |            |
# |    entropy_loss       | -41.5      |
# |    explained_variance | -0.217     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1999       |
# |    policy_loss        | -99.2      |
# |    reward             | -0.4620678 |
# |    std                | 1.01       |
# |    value_loss         | 9.93       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 103       |
# |    iterations         | 2100      |
# |    time_elapsed       | 101       |
# |    total_timesteps    | 10500     |
# | train/                |           |
# |    entropy_loss       | -41.5     |
# |    explained_variance | -0.0671   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2099      |
# |    policy_loss        | 81.2      |
# |    reward             | 0.9198489 |
# |    std                | 1.01      |
# |    value_loss         | 5.24      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 103        |
# |    iterations         | 2200       |
# |    time_elapsed       | 106        |
# |    total_timesteps    | 11000      |
# | train/                |            |
# |    entropy_loss       | -41.6      |
# |    explained_variance | 7.12e-05   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2199       |
# |    policy_loss        | -47.9      |
# |    reward             | -6.9455676 |
# |    std                | 1.01       |
# |    value_loss         | 5.21       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 103       |
# |    iterations         | 2300      |
# |    time_elapsed       | 111       |
# |    total_timesteps    | 11500     |
# | train/                |           |
# |    entropy_loss       | -41.6     |
# |    explained_variance | -0.00269  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2299      |
# |    policy_loss        | -2.13e+03 |
# |    reward             | -14.95791 |
# |    std                | 1.02      |
# |    value_loss         | 2.58e+03  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 103       |
# |    iterations         | 2400      |
# |    time_elapsed       | 116       |
# |    total_timesteps    | 12000     |
# | train/                |           |
# |    entropy_loss       | -41.6     |
# |    explained_variance | 0.000189  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2399      |
# |    policy_loss        | -7.72     |
# |    reward             | 1.5893576 |
# |    std                | 1.02      |
# |    value_loss         | 2.45      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 103         |
# |    iterations         | 2500        |
# |    time_elapsed       | 121         |
# |    total_timesteps    | 12500       |
# | train/                |             |
# |    entropy_loss       | -41.7       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 2499        |
# |    policy_loss        | -92.1       |
# |    reward             | -0.11462189 |
# |    std                | 1.02        |
# |    value_loss         | 5.12        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 102       |
# |    iterations         | 2600      |
# |    time_elapsed       | 126       |
# |    total_timesteps    | 13000     |
# | train/                |           |
# |    entropy_loss       | -41.7     |
# |    explained_variance | -0.00429  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2599      |
# |    policy_loss        | -13.9     |
# |    reward             | 1.6566278 |
# |    std                | 1.02      |
# |    value_loss         | 0.342     |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 102        |
# |    iterations         | 2700       |
# |    time_elapsed       | 131        |
# |    total_timesteps    | 13500      |
# | train/                |            |
# |    entropy_loss       | -41.7      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2699       |
# |    policy_loss        | 34.1       |
# |    reward             | -1.2346824 |
# |    std                | 1.02       |
# |    value_loss         | 0.913      |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 102       |
# |    iterations         | 2800      |
# |    time_elapsed       | 136       |
# |    total_timesteps    | 14000     |
# | train/                |           |
# |    entropy_loss       | -41.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2799      |
# |    policy_loss        | 368       |
# |    reward             | 1.2148285 |
# |    std                | 1.02      |
# |    value_loss         | 77.4      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 102       |
# |    iterations         | 2900      |
# |    time_elapsed       | 141       |
# |    total_timesteps    | 14500     |
# | train/                |           |
# |    entropy_loss       | -41.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2899      |
# |    policy_loss        | -116      |
# |    reward             | 1.7351062 |
# |    std                | 1.02      |
# |    value_loss         | 7.82      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 102       |
# |    iterations         | 3000      |
# |    time_elapsed       | 146       |
# |    total_timesteps    | 15000     |
# | train/                |           |
# |    entropy_loss       | -41.7     |
# |    explained_variance | 0.0225    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2999      |
# |    policy_loss        | 38.9      |
# |    reward             | 0.3277289 |
# |    std                | 1.02      |
# |    value_loss         | 2.03      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 102        |
# |    iterations         | 3100       |
# |    time_elapsed       | 150        |
# |    total_timesteps    | 15500      |
# | train/                |            |
# |    entropy_loss       | -41.8      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3099       |
# |    policy_loss        | -3.76      |
# |    reward             | -0.5026625 |
# |    std                | 1.02       |
# |    value_loss         | 0.504      |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 103        |
# |    iterations         | 3200       |
# |    time_elapsed       | 155        |
# |    total_timesteps    | 16000      |
# | train/                |            |
# |    entropy_loss       | -41.7      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3199       |
# |    policy_loss        | -292       |
# |    reward             | -2.0564313 |
# |    std                | 1.02       |
# |    value_loss         | 94.5       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 103        |
# |    iterations         | 3300       |
# |    time_elapsed       | 159        |
# |    total_timesteps    | 16500      |
# | train/                |            |
# |    entropy_loss       | -41.7      |
# |    explained_variance | -0.0157    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3299       |
# |    policy_loss        | 94.5       |
# |    reward             | -1.0083501 |
# |    std                | 1.02       |
# |    value_loss         | 8.9        |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 103      |
# |    iterations         | 3400     |
# |    time_elapsed       | 164      |
# |    total_timesteps    | 17000    |
# | train/                |          |
# |    entropy_loss       | -41.6    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3399     |
# |    policy_loss        | 228      |
# |    reward             | 7.204868 |
# |    std                | 1.02     |
# |    value_loss         | 49.9     |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 103        |
# |    iterations         | 3500       |
# |    time_elapsed       | 168        |
# |    total_timesteps    | 17500      |
# | train/                |            |
# |    entropy_loss       | -41.6      |
# |    explained_variance | 0.0188     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3499       |
# |    policy_loss        | 146        |
# |    reward             | 0.07126763 |
# |    std                | 1.02       |
# |    value_loss         | 20.4       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 103       |
# |    iterations         | 3600      |
# |    time_elapsed       | 173       |
# |    total_timesteps    | 18000     |
# | train/                |           |
# |    entropy_loss       | -41.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3599      |
# |    policy_loss        | -94.8     |
# |    reward             | 1.1817983 |
# |    std                | 1.02      |
# |    value_loss         | 8.51      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 103         |
# |    iterations         | 3700        |
# |    time_elapsed       | 179         |
# |    total_timesteps    | 18500       |
# | train/                |             |
# |    entropy_loss       | -41.6       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 3699        |
# |    policy_loss        | 201         |
# |    reward             | -0.49598026 |
# |    std                | 1.02        |
# |    value_loss         | 22.5        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 103        |
# |    iterations         | 3800       |
# |    time_elapsed       | 184        |
# |    total_timesteps    | 19000      |
# | train/                |            |
# |    entropy_loss       | -41.7      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3799       |
# |    policy_loss        | 92.8       |
# |    reward             | 0.90399176 |
# |    std                | 1.02       |
# |    value_loss         | 5.8        |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 102       |
# |    iterations         | 3900      |
# |    time_elapsed       | 190       |
# |    total_timesteps    | 19500     |
# | train/                |           |
# |    entropy_loss       | -41.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3899      |
# |    policy_loss        | -241      |
# |    reward             | 2.7298927 |
# |    std                | 1.02      |
# |    value_loss         | 37.2      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 102      |
# |    iterations         | 4000     |
# |    time_elapsed       | 195      |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -41.8    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3999     |
# |    policy_loss        | -218     |
# |    reward             | 7.335054 |
# |    std                | 1.02     |
# |    value_loss         | 42.9     |
# ------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 102          |
# |    iterations         | 4100         |
# |    time_elapsed       | 200          |
# |    total_timesteps    | 20500        |
# | train/                |              |
# |    entropy_loss       | -41.7        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 4099         |
# |    policy_loss        | 4.89         |
# |    reward             | -0.010516474 |
# |    std                | 1.02         |
# |    value_loss         | 1.2          |
# ----------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 102       |
# |    iterations         | 4200      |
# |    time_elapsed       | 205       |
# |    total_timesteps    | 21000     |
# | train/                |           |
# |    entropy_loss       | -41.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4199      |
# |    policy_loss        | -145      |
# |    reward             | 1.0938467 |
# |    std                | 1.02      |
# |    value_loss         | 15        |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 102       |
# |    iterations         | 4300      |
# |    time_elapsed       | 210       |
# |    total_timesteps    | 21500     |
# | train/                |           |
# |    entropy_loss       | -41.7     |
# |    explained_variance | 0.00841   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4299      |
# |    policy_loss        | -226      |
# |    reward             | 4.0572066 |
# |    std                | 1.02      |
# |    value_loss         | 29.4      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 102       |
# |    iterations         | 4400      |
# |    time_elapsed       | 215       |
# |    total_timesteps    | 22000     |
# | train/                |           |
# |    entropy_loss       | -41.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4399      |
# |    policy_loss        | 88.5      |
# |    reward             | 3.0571003 |
# |    std                | 1.02      |
# |    value_loss         | 18.7      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 102       |
# |    iterations         | 4500      |
# |    time_elapsed       | 220       |
# |    total_timesteps    | 22500     |
# | train/                |           |
# |    entropy_loss       | -41.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4499      |
# |    policy_loss        | 178       |
# |    reward             | 1.4729546 |
# |    std                | 1.02      |
# |    value_loss         | 20.5      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 101      |
# |    iterations         | 4600     |
# |    time_elapsed       | 225      |
# |    total_timesteps    | 23000    |
# | train/                |          |
# |    entropy_loss       | -41.7    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4599     |
# |    policy_loss        | 194      |
# |    reward             | 7.666167 |
# |    std                | 1.02     |
# |    value_loss         | 40.1     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 101       |
# |    iterations         | 4700      |
# |    time_elapsed       | 230       |
# |    total_timesteps    | 23500     |
# | train/                |           |
# |    entropy_loss       | -41.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4699      |
# |    policy_loss        | -127      |
# |    reward             | 1.0841942 |
# |    std                | 1.02      |
# |    value_loss         | 14.7      |
# -------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 101          |
# |    iterations         | 4800         |
# |    time_elapsed       | 235          |
# |    total_timesteps    | 24000        |
# | train/                |              |
# |    entropy_loss       | -41.7        |
# |    explained_variance | 5.96e-08     |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 4799         |
# |    policy_loss        | -219         |
# |    reward             | -0.057358798 |
# |    std                | 1.02         |
# |    value_loss         | 39.1         |
# ----------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 101       |
# |    iterations         | 4900      |
# |    time_elapsed       | 240       |
# |    total_timesteps    | 24500     |
# | train/                |           |
# |    entropy_loss       | -41.7     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4899      |
# |    policy_loss        | 47.1      |
# |    reward             | 1.5277109 |
# |    std                | 1.02      |
# |    value_loss         | 2.44      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 101       |
# |    iterations         | 5000      |
# |    time_elapsed       | 247       |
# |    total_timesteps    | 25000     |
# | train/                |           |
# |    entropy_loss       | -41.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4999      |
# |    policy_loss        | -33.1     |
# |    reward             | 1.7014804 |
# |    std                | 1.02      |
# |    value_loss         | 3.63      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 101       |
# |    iterations         | 5100      |
# |    time_elapsed       | 252       |
# |    total_timesteps    | 25500     |
# | train/                |           |
# |    entropy_loss       | -41.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5099      |
# |    policy_loss        | 411       |
# |    reward             | 1.0158439 |
# |    std                | 1.02      |
# |    value_loss         | 109       |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 100       |
# |    iterations         | 5200      |
# |    time_elapsed       | 257       |
# |    total_timesteps    | 26000     |
# | train/                |           |
# |    entropy_loss       | -41.8     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5199      |
# |    policy_loss        | -459      |
# |    reward             | 11.824823 |
# |    std                | 1.02      |
# |    value_loss         | 228       |
# -------------------------------------
# day: 2892, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 9575124.71
# total_reward: 8575124.71
# total_cost: 43770.13
# total_trades: 55377
# Sharpe: 1.088
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 100       |
# |    iterations         | 5300      |
# |    time_elapsed       | 262       |
# |    total_timesteps    | 26500     |
# | train/                |           |
# |    entropy_loss       | -41.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5299      |
# |    policy_loss        | -19.4     |
# |    reward             | 0.6621652 |
# |    std                | 1.02      |
# |    value_loss         | 0.316     |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 100        |
# |    iterations         | 5400       |
# |    time_elapsed       | 268        |
# |    total_timesteps    | 27000      |
# | train/                |            |
# |    entropy_loss       | -41.8      |
# |    explained_variance | 5.96e-08   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5399       |
# |    policy_loss        | -148       |
# |    reward             | 0.12824596 |
# |    std                | 1.02       |
# |    value_loss         | 15.9       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 100       |
# |    iterations         | 5500      |
# |    time_elapsed       | 273       |
# |    total_timesteps    | 27500     |
# | train/                |           |
# |    entropy_loss       | -41.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5499      |
# |    policy_loss        | -34.2     |
# |    reward             | 3.5605395 |
# |    std                | 1.02      |
# |    value_loss         | 11.4      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 100         |
# |    iterations         | 5600        |
# |    time_elapsed       | 278         |
# |    total_timesteps    | 28000       |
# | train/                |             |
# |    entropy_loss       | -41.8       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 5599        |
# |    policy_loss        | -192        |
# |    reward             | -0.14947428 |
# |    std                | 1.02        |
# |    value_loss         | 25.8        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 100       |
# |    iterations         | 5700      |
# |    time_elapsed       | 283       |
# |    total_timesteps    | 28500     |
# | train/                |           |
# |    entropy_loss       | -41.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5699      |
# |    policy_loss        | -502      |
# |    reward             | -9.761749 |
# |    std                | 1.02      |
# |    value_loss         | 198       |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 100       |
# |    iterations         | 5800      |
# |    time_elapsed       | 288       |
# |    total_timesteps    | 29000     |
# | train/                |           |
# |    entropy_loss       | -41.6     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5799      |
# |    policy_loss        | -15.6     |
# |    reward             | 1.8116534 |
# |    std                | 1.02      |
# |    value_loss         | 4.82      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 100       |
# |    iterations         | 5900      |
# |    time_elapsed       | 292       |
# |    total_timesteps    | 29500     |
# | train/                |           |
# |    entropy_loss       | -41.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5899      |
# |    policy_loss        | -23.2     |
# |    reward             | 0.2528696 |
# |    std                | 1.02      |
# |    value_loss         | 1.1       |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 100        |
# |    iterations         | 6000       |
# |    time_elapsed       | 297        |
# |    total_timesteps    | 30000      |
# | train/                |            |
# |    entropy_loss       | -41.8      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5999       |
# |    policy_loss        | 51.6       |
# |    reward             | -1.1874826 |
# |    std                | 1.02       |
# |    value_loss         | 1.8        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 100        |
# |    iterations         | 6100       |
# |    time_elapsed       | 302        |
# |    total_timesteps    | 30500      |
# | train/                |            |
# |    entropy_loss       | -41.9      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6099       |
# |    policy_loss        | -24.3      |
# |    reward             | -1.1490939 |
# |    std                | 1.03       |
# |    value_loss         | 1.18       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 100         |
# |    iterations         | 6200        |
# |    time_elapsed       | 307         |
# |    total_timesteps    | 31000       |
# | train/                |             |
# |    entropy_loss       | -41.8       |
# |    explained_variance | -1.19e-07   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 6199        |
# |    policy_loss        | 13.7        |
# |    reward             | -0.02120826 |
# |    std                | 1.03        |
# |    value_loss         | 0.55        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 100       |
# |    iterations         | 6300      |
# |    time_elapsed       | 312       |
# |    total_timesteps    | 31500     |
# | train/                |           |
# |    entropy_loss       | -41.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6299      |
# |    policy_loss        | 354       |
# |    reward             | 10.359747 |
# |    std                | 1.03      |
# |    value_loss         | 105       |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 100       |
# |    iterations         | 6400      |
# |    time_elapsed       | 317       |
# |    total_timesteps    | 32000     |
# | train/                |           |
# |    entropy_loss       | -41.9     |
# |    explained_variance | 0.0496    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6399      |
# |    policy_loss        | 111       |
# |    reward             | 1.7239735 |
# |    std                | 1.03      |
# |    value_loss         | 7.24      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 100        |
# |    iterations         | 6500       |
# |    time_elapsed       | 322        |
# |    total_timesteps    | 32500      |
# | train/                |            |
# |    entropy_loss       | -41.9      |
# |    explained_variance | 5.96e-08   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6499       |
# |    policy_loss        | 6.69       |
# |    reward             | -3.3395498 |
# |    std                | 1.03       |
# |    value_loss         | 2.73       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 100        |
# |    iterations         | 6600       |
# |    time_elapsed       | 327        |
# |    total_timesteps    | 33000      |
# | train/                |            |
# |    entropy_loss       | -42        |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6599       |
# |    policy_loss        | -18.3      |
# |    reward             | -0.4807742 |
# |    std                | 1.03       |
# |    value_loss         | 3.04       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 100       |
# |    iterations         | 6700      |
# |    time_elapsed       | 332       |
# |    total_timesteps    | 33500     |
# | train/                |           |
# |    entropy_loss       | -41.9     |
# |    explained_variance | 0.00476   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6699      |
# |    policy_loss        | -987      |
# |    reward             | -8.172284 |
# |    std                | 1.03      |
# |    value_loss         | 715       |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 100       |
# |    iterations         | 6800      |
# |    time_elapsed       | 336       |
# |    total_timesteps    | 34000     |
# | train/                |           |
# |    entropy_loss       | -41.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6799      |
# |    policy_loss        | -197      |
# |    reward             | 2.2854795 |
# |    std                | 1.03      |
# |    value_loss         | 30.8      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 100        |
# |    iterations         | 6900       |
# |    time_elapsed       | 341        |
# |    total_timesteps    | 34500      |
# | train/                |            |
# |    entropy_loss       | -41.9      |
# |    explained_variance | -0.00257   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6899       |
# |    policy_loss        | -579       |
# |    reward             | 0.11797466 |
# |    std                | 1.03       |
# |    value_loss         | 287        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 100        |
# |    iterations         | 7000       |
# |    time_elapsed       | 346        |
# |    total_timesteps    | 35000      |
# | train/                |            |
# |    entropy_loss       | -41.9      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6999       |
# |    policy_loss        | 84.9       |
# |    reward             | 0.16209899 |
# |    std                | 1.03       |
# |    value_loss         | 4.33       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 100       |
# |    iterations         | 7100      |
# |    time_elapsed       | 351       |
# |    total_timesteps    | 35500     |
# | train/                |           |
# |    entropy_loss       | -41.9     |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7099      |
# |    policy_loss        | 49.4      |
# |    reward             | 2.1776016 |
# |    std                | 1.03      |
# |    value_loss         | 2.09      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 100       |
# |    iterations         | 7200      |
# |    time_elapsed       | 356       |
# |    total_timesteps    | 36000     |
# | train/                |           |
# |    entropy_loss       | -41.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7199      |
# |    policy_loss        | -263      |
# |    reward             | 1.8878658 |
# |    std                | 1.03      |
# |    value_loss         | 40.2      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 100       |
# |    iterations         | 7300      |
# |    time_elapsed       | 361       |
# |    total_timesteps    | 36500     |
# | train/                |           |
# |    entropy_loss       | -41.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7299      |
# |    policy_loss        | 206       |
# |    reward             | 1.2024975 |
# |    std                | 1.03      |
# |    value_loss         | 31.4      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 100       |
# |    iterations         | 7400      |
# |    time_elapsed       | 366       |
# |    total_timesteps    | 37000     |
# | train/                |           |
# |    entropy_loss       | -41.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7399      |
# |    policy_loss        | -129      |
# |    reward             | 1.1738844 |
# |    std                | 1.03      |
# |    value_loss         | 18.7      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 100        |
# |    iterations         | 7500       |
# |    time_elapsed       | 371        |
# |    total_timesteps    | 37500      |
# | train/                |            |
# |    entropy_loss       | -41.9      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7499       |
# |    policy_loss        | 237        |
# |    reward             | -5.8395286 |
# |    std                | 1.03       |
# |    value_loss         | 33.5       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 100       |
# |    iterations         | 7600      |
# |    time_elapsed       | 376       |
# |    total_timesteps    | 38000     |
# | train/                |           |
# |    entropy_loss       | -41.9     |
# |    explained_variance | 0.0798    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7599      |
# |    policy_loss        | -18.4     |
# |    reward             | 1.4785215 |
# |    std                | 1.03      |
# |    value_loss         | 1.28      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 100       |
# |    iterations         | 7700      |
# |    time_elapsed       | 381       |
# |    total_timesteps    | 38500     |
# | train/                |           |
# |    entropy_loss       | -41.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7699      |
# |    policy_loss        | -186      |
# |    reward             | 1.4101536 |
# |    std                | 1.03      |
# |    value_loss         | 24.5      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 100         |
# |    iterations         | 7800        |
# |    time_elapsed       | 386         |
# |    total_timesteps    | 39000       |
# | train/                |             |
# |    entropy_loss       | -42         |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 7799        |
# |    policy_loss        | 3.81        |
# |    reward             | -0.09161003 |
# |    std                | 1.03        |
# |    value_loss         | 1.91        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 100       |
# |    iterations         | 7900      |
# |    time_elapsed       | 391       |
# |    total_timesteps    | 39500     |
# | train/                |           |
# |    entropy_loss       | -42       |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7899      |
# |    policy_loss        | 45.1      |
# |    reward             | 5.334459  |
# |    std                | 1.03      |
# |    value_loss         | 30.4      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 100        |
# |    iterations         | 8000       |
# |    time_elapsed       | 396        |
# |    total_timesteps    | 40000      |
# | train/                |            |
# |    entropy_loss       | -42        |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7999       |
# |    policy_loss        | -263       |
# |    reward             | -3.8185105 |
# |    std                | 1.03       |
# |    value_loss         | 56.5       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 100      |
# |    iterations         | 8100     |
# |    time_elapsed       | 401      |
# |    total_timesteps    | 40500    |
# | train/                |          |
# |    entropy_loss       | -42      |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8099     |
# |    policy_loss        | 378      |
# |    reward             | 9.135098 |
# |    std                | 1.03     |
# |    value_loss         | 117      |
# ------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 100         |
# |    iterations         | 8200        |
# |    time_elapsed       | 406         |
# |    total_timesteps    | 41000       |
# | train/                |             |
# |    entropy_loss       | -42.1       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 8199        |
# |    policy_loss        | 49.7        |
# |    reward             | -0.30013168 |
# |    std                | 1.03        |
# |    value_loss         | 2.24        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 100        |
# |    iterations         | 8300       |
# |    time_elapsed       | 411        |
# |    total_timesteps    | 41500      |
# | train/                |            |
# |    entropy_loss       | -42.1      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8299       |
# |    policy_loss        | 55.4       |
# |    reward             | -1.8187155 |
# |    std                | 1.03       |
# |    value_loss         | 2.54       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 100       |
# |    iterations         | 8400      |
# |    time_elapsed       | 416       |
# |    total_timesteps    | 42000     |
# | train/                |           |
# |    entropy_loss       | -42       |
# |    explained_variance | 0.00516   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8399      |
# |    policy_loss        | 119       |
# |    reward             | -5.858297 |
# |    std                | 1.03      |
# |    value_loss         | 11.3      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 100        |
# |    iterations         | 8500       |
# |    time_elapsed       | 421        |
# |    total_timesteps    | 42500      |
# | train/                |            |
# |    entropy_loss       | -42        |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8499       |
# |    policy_loss        | -260       |
# |    reward             | -1.6047884 |
# |    std                | 1.03       |
# |    value_loss         | 42.3       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 100        |
# |    iterations         | 8600       |
# |    time_elapsed       | 426        |
# |    total_timesteps    | 43000      |
# | train/                |            |
# |    entropy_loss       | -42.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8599       |
# |    policy_loss        | 245        |
# |    reward             | -10.710802 |
# |    std                | 1.03       |
# |    value_loss         | 46.1       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 100       |
# |    iterations         | 8700      |
# |    time_elapsed       | 431       |
# |    total_timesteps    | 43500     |
# | train/                |           |
# |    entropy_loss       | -42       |
# |    explained_variance | -0.00333  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8699      |
# |    policy_loss        | -10.3     |
# |    reward             | 0.6292854 |
# |    std                | 1.03      |
# |    value_loss         | 1.6       |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 100         |
# |    iterations         | 8800        |
# |    time_elapsed       | 436         |
# |    total_timesteps    | 44000       |
# | train/                |             |
# |    entropy_loss       | -42         |
# |    explained_variance | -1.19e-07   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 8799        |
# |    policy_loss        | -48.3       |
# |    reward             | -0.12352531 |
# |    std                | 1.03        |
# |    value_loss         | 1.72        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 100       |
# |    iterations         | 8900      |
# |    time_elapsed       | 441       |
# |    total_timesteps    | 44500     |
# | train/                |           |
# |    entropy_loss       | -42.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8899      |
# |    policy_loss        | -29.8     |
# |    reward             | 0.8567227 |
# |    std                | 1.04      |
# |    value_loss         | 2.74      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 100         |
# |    iterations         | 9000        |
# |    time_elapsed       | 446         |
# |    total_timesteps    | 45000       |
# | train/                |             |
# |    entropy_loss       | -42.1       |
# |    explained_variance | -0.0705     |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 8999        |
# |    policy_loss        | 7.15        |
# |    reward             | -0.49330065 |
# |    std                | 1.03        |
# |    value_loss         | 11.4        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 100       |
# |    iterations         | 9100      |
# |    time_elapsed       | 451       |
# |    total_timesteps    | 45500     |
# | train/                |           |
# |    entropy_loss       | -42.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9099      |
# |    policy_loss        | 150       |
# |    reward             | 1.2350318 |
# |    std                | 1.04      |
# |    value_loss         | 16.9      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 100       |
# |    iterations         | 9200      |
# |    time_elapsed       | 456       |
# |    total_timesteps    | 46000     |
# | train/                |           |
# |    entropy_loss       | -42.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9199      |
# |    policy_loss        | -91.5     |
# |    reward             | 5.7737904 |
# |    std                | 1.04      |
# |    value_loss         | 21.9      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 100       |
# |    iterations         | 9300      |
# |    time_elapsed       | 461       |
# |    total_timesteps    | 46500     |
# | train/                |           |
# |    entropy_loss       | -42.2     |
# |    explained_variance | -0.058    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9299      |
# |    policy_loss        | -191      |
# |    reward             | 0.2810126 |
# |    std                | 1.04      |
# |    value_loss         | 25.7      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 100        |
# |    iterations         | 9400       |
# |    time_elapsed       | 466        |
# |    total_timesteps    | 47000      |
# | train/                |            |
# |    entropy_loss       | -42.2      |
# |    explained_variance | 5.96e-08   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9399       |
# |    policy_loss        | 161        |
# |    reward             | -2.2353332 |
# |    std                | 1.04       |
# |    value_loss         | 14.9       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 100        |
# |    iterations         | 9500       |
# |    time_elapsed       | 471        |
# |    total_timesteps    | 47500      |
# | train/                |            |
# |    entropy_loss       | -42.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9499       |
# |    policy_loss        | -4.89      |
# |    reward             | -1.3043959 |
# |    std                | 1.04       |
# |    value_loss         | 1.31       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 100        |
# |    iterations         | 9600       |
# |    time_elapsed       | 476        |
# |    total_timesteps    | 48000      |
# | train/                |            |
# |    entropy_loss       | -42.3      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9599       |
# |    policy_loss        | -637       |
# |    reward             | 0.34357896 |
# |    std                | 1.04       |
# |    value_loss         | 226        |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 100       |
# |    iterations         | 9700      |
# |    time_elapsed       | 481       |
# |    total_timesteps    | 48500     |
# | train/                |           |
# |    entropy_loss       | -42.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9699      |
# |    policy_loss        | 172       |
# |    reward             | -2.594704 |
# |    std                | 1.04      |
# |    value_loss         | 16.7      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 100      |
# |    iterations         | 9800     |
# |    time_elapsed       | 485      |
# |    total_timesteps    | 49000    |
# | train/                |          |
# |    entropy_loss       | -42.4    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9799     |
# |    policy_loss        | -12.3    |
# |    reward             | 5.654484 |
# |    std                | 1.05     |
# |    value_loss         | 44.4     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 100       |
# |    iterations         | 9900      |
# |    time_elapsed       | 490       |
# |    total_timesteps    | 49500     |
# | train/                |           |
# |    entropy_loss       | -42.3     |
# |    explained_variance | -0.085    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9899      |
# |    policy_loss        | 28.4      |
# |    reward             | 0.8946478 |
# |    std                | 1.04      |
# |    value_loss         | 0.678     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 100       |
# |    iterations         | 10000     |
# |    time_elapsed       | 495       |
# |    total_timesteps    | 50000     |
# | train/                |           |
# |    entropy_loss       | -42.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9999      |
# |    policy_loss        | 13.3      |
# |    reward             | -1.218432 |
# |    std                | 1.05      |
# |    value_loss         | 1.37      |
# -------------------------------------

# %% [markdown]
# ### Agent 2: DDPG

# %%
agent = DRLAgent(env = env_train)
model_ddpg = agent.get_model("ddpg")
# Out:
# {'batch_size': 128, 'buffer_size': 50000, 'learning_rate': 0.001}
# Using cpu device

# %%
trained_ddpg = agent.train_model(model=model_ddpg, 
                             tb_log_name='ddpg',
                             total_timesteps=50000)
# Out:
# day: 2892, episode: 20
# begin_total_asset: 1000000.00
# end_total_asset: 4410346.05
# total_reward: 3410346.05
# total_cost: 5979.69
# total_trades: 43332
# Sharpe: 0.791
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 45        |
# |    time_elapsed    | 255       |
# |    total_timesteps | 11572     |
# | train/             |           |
# |    actor_loss      | 27.7      |
# |    critic_loss     | 110       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 8679      |
# |    reward          | 5.7790976 |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 41        |
# |    time_elapsed    | 561       |
# |    total_timesteps | 23144     |
# | train/             |           |
# |    actor_loss      | 7.61      |
# |    critic_loss     | 5.21      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 20251     |
# |    reward          | 5.7790976 |
# ----------------------------------
# day: 2892, episode: 30
# begin_total_asset: 1000000.00
# end_total_asset: 4363429.08
# total_reward: 3363429.08
# total_cost: 999.00
# total_trades: 37596
# Sharpe: 0.735
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 40        |
# |    time_elapsed    | 863       |
# |    total_timesteps | 34716     |
# | train/             |           |
# |    actor_loss      | -0.233    |
# |    critic_loss     | 2.91      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 31823     |
# |    reward          | 5.7790976 |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 39        |
# |    time_elapsed    | 1160      |
# |    total_timesteps | 46288     |
# | train/             |           |
# |    actor_loss      | -3.48     |
# |    critic_loss     | 1.81      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 43395     |
# |    reward          | 5.7790976 |
# ----------------------------------

# %% [markdown]
# ### Agent 3: PPO

# %%
agent = DRLAgent(env = env_train)
PPO_PARAMS = {
    "n_steps": 2048,
    "ent_coef": 0.01,
    "learning_rate": 0.00025,
    "batch_size": 128,
}
model_ppo = agent.get_model("ppo",model_kwargs = PPO_PARAMS)
# Out:
# {'n_steps': 2048, 'ent_coef': 0.01, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device

# %%
trained_ppo = agent.train_model(model=model_ppo, 
                             tb_log_name='ppo',
                             total_timesteps=50000)
# Out:
# ----------------------------------
# | time/              |           |
# |    fps             | 130       |
# |    iterations      | 1         |
# |    time_elapsed    | 15        |
# |    total_timesteps | 2048      |
# | train/             |           |
# |    reward          | 0.3080122 |
# ----------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 127         |
# |    iterations           | 2           |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.014548222 |
# |    clip_fraction        | 0.213       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | -0.0038     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 4.32        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0319     |
# |    reward               | 1.0294412   |
# |    std                  | 1           |
# |    value_loss           | 12.1        |
# -----------------------------------------
# day: 2892, episode: 40
# begin_total_asset: 1000000.00
# end_total_asset: 3891384.48
# total_reward: 2891384.48
# total_cost: 343555.76
# total_trades: 80448
# Sharpe: 0.766
# =================================
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 126        |
# |    iterations           | 3          |
# |    time_elapsed         | 48         |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.03185212 |
# |    clip_fraction        | 0.223      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -41.2      |
# |    explained_variance   | 0.00594    |
# |    learning_rate        | 0.00025    |
# |    loss                 | 26         |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.0188    |
# |    reward               | -0.8203445 |
# |    std                  | 1          |
# |    value_loss           | 47.4       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 4           |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.014678076 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | 0.00144     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 22.5        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0196     |
# |    reward               | 1.4997915   |
# |    std                  | 1           |
# |    value_loss           | 59.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 5           |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.016879577 |
# |    clip_fraction        | 0.19        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | -0.00946    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 9.38        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0227     |
# |    reward               | 4.126302    |
# |    std                  | 1.01        |
# |    value_loss           | 20.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 110         |
# |    iterations           | 6           |
# |    time_elapsed         | 111         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.020263767 |
# |    clip_fraction        | 0.23        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.4       |
# |    explained_variance   | -0.00172    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 23          |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0199     |
# |    reward               | 2.1437676   |
# |    std                  | 1.01        |
# |    value_loss           | 41.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 109         |
# |    iterations           | 7           |
# |    time_elapsed         | 130         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.019493457 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.4       |
# |    explained_variance   | 0.00206     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 50.9        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0194     |
# |    reward               | 0.6887793   |
# |    std                  | 1.01        |
# |    value_loss           | 76.4        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 109        |
# |    iterations           | 8          |
# |    time_elapsed         | 149        |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.02171735 |
# |    clip_fraction        | 0.247      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -41.5      |
# |    explained_variance   | -0.00206   |
# |    learning_rate        | 0.00025    |
# |    loss                 | 16.2       |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.0184    |
# |    reward               | 1.2398497  |
# |    std                  | 1.01       |
# |    value_loss           | 36.8       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 109        |
# |    iterations           | 9          |
# |    time_elapsed         | 168        |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.02912468 |
# |    clip_fraction        | 0.258      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -41.6      |
# |    explained_variance   | -0.00107   |
# |    learning_rate        | 0.00025    |
# |    loss                 | 25.7       |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.0181    |
# |    reward               | 0.83210516 |
# |    std                  | 1.02       |
# |    value_loss           | 51.6       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 109        |
# |    iterations           | 10         |
# |    time_elapsed         | 186        |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.02425318 |
# |    clip_fraction        | 0.259      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -41.6      |
# |    explained_variance   | 0.000829   |
# |    learning_rate        | 0.00025    |
# |    loss                 | 37.3       |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.0104    |
# |    reward               | 0.4606104  |
# |    std                  | 1.02       |
# |    value_loss           | 66.2       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 110         |
# |    iterations           | 11          |
# |    time_elapsed         | 203         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.030215764 |
# |    clip_fraction        | 0.287       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.7       |
# |    explained_variance   | -0.0157     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 27.6        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0137     |
# |    reward               | -0.15703589 |
# |    std                  | 1.02        |
# |    value_loss           | 67.4        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 110        |
# |    iterations           | 12         |
# |    time_elapsed         | 222        |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.02208773 |
# |    clip_fraction        | 0.26       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -41.7      |
# |    explained_variance   | -0.0208    |
# |    learning_rate        | 0.00025    |
# |    loss                 | 5.62       |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.013     |
# |    reward               | 0.07306353 |
# |    std                  | 1.02       |
# |    value_loss           | 14         |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 110         |
# |    iterations           | 13          |
# |    time_elapsed         | 241         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.023905627 |
# |    clip_fraction        | 0.215       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.8       |
# |    explained_variance   | 0.0144      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 23          |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0144     |
# |    reward               | 0.391748    |
# |    std                  | 1.02        |
# |    value_loss           | 46.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 108         |
# |    iterations           | 14          |
# |    time_elapsed         | 263         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.018790629 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.8       |
# |    explained_variance   | 0.0168      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 19.8        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0183     |
# |    reward               | 0.9593707   |
# |    std                  | 1.02        |
# |    value_loss           | 53.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 108         |
# |    iterations           | 15          |
# |    time_elapsed         | 283         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.026090726 |
# |    clip_fraction        | 0.257       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.8       |
# |    explained_variance   | 0.00123     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 6.47        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0128     |
# |    reward               | 3.2890122   |
# |    std                  | 1.03        |
# |    value_loss           | 16.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 108         |
# |    iterations           | 16          |
# |    time_elapsed         | 303         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.022994297 |
# |    clip_fraction        | 0.21        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.9       |
# |    explained_variance   | 0.00933     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 7.82        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.019      |
# |    reward               | -0.1491511  |
# |    std                  | 1.03        |
# |    value_loss           | 34.8        |
# -----------------------------------------
# day: 2892, episode: 50
# begin_total_asset: 1000000.00
# end_total_asset: 3062683.18
# total_reward: 2062683.18
# total_cost: 320962.82
# total_trades: 78391
# Sharpe: 0.606
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 107         |
# |    iterations           | 17          |
# |    time_elapsed         | 322         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.018451352 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.9       |
# |    explained_variance   | -0.00557    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 60.3        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.015      |
# |    reward               | 0.43945423  |
# |    std                  | 1.03        |
# |    value_loss           | 132         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 107         |
# |    iterations           | 18          |
# |    time_elapsed         | 342         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.020122796 |
# |    clip_fraction        | 0.211       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42         |
# |    explained_variance   | 0.000745    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 80.3        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0195     |
# |    reward               | 0.22365083  |
# |    std                  | 1.03        |
# |    value_loss           | 105         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 107        |
# |    iterations           | 19         |
# |    time_elapsed         | 363        |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.03206852 |
# |    clip_fraction        | 0.298      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -42        |
# |    explained_variance   | -0.0603    |
# |    learning_rate        | 0.00025    |
# |    loss                 | 3.72       |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.0185    |
# |    reward               | 0.01971715 |
# |    std                  | 1.03       |
# |    value_loss           | 8.95       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 106         |
# |    iterations           | 20          |
# |    time_elapsed         | 383         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.02798953  |
# |    clip_fraction        | 0.257       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.1       |
# |    explained_variance   | 0.00573     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 14.9        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0167     |
# |    reward               | -0.34162483 |
# |    std                  | 1.03        |
# |    value_loss           | 36.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 106         |
# |    iterations           | 21          |
# |    time_elapsed         | 404         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.023938105 |
# |    clip_fraction        | 0.268       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.2       |
# |    explained_variance   | 0.000123    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 30.7        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0145     |
# |    reward               | -5.049646   |
# |    std                  | 1.04        |
# |    value_loss           | 47.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 106         |
# |    iterations           | 22          |
# |    time_elapsed         | 424         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.018246204 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.2       |
# |    explained_variance   | -0.0612     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 6.86        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0175     |
# |    reward               | 2.4483583   |
# |    std                  | 1.04        |
# |    value_loss           | 17.9        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 105          |
# |    iterations           | 23           |
# |    time_elapsed         | 445          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.02363077   |
# |    clip_fraction        | 0.237        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -42.3        |
# |    explained_variance   | -0.013       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 32.2         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.019       |
# |    reward               | -0.021391561 |
# |    std                  | 1.04         |
# |    value_loss           | 43.3         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 105         |
# |    iterations           | 24          |
# |    time_elapsed         | 466         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.031175751 |
# |    clip_fraction        | 0.298       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.3       |
# |    explained_variance   | 0.0174      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 10.8        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0146     |
# |    reward               | 6.30475     |
# |    std                  | 1.04        |
# |    value_loss           | 37.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 105         |
# |    iterations           | 25          |
# |    time_elapsed         | 487         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.031300217 |
# |    clip_fraction        | 0.303       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.4       |
# |    explained_variance   | -0.00395    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 12.2        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0142     |
# |    reward               | 0.6488076   |
# |    std                  | 1.05        |
# |    value_loss           | 52.2        |
# -----------------------------------------

# %% [markdown]
# ### Agent 4: TD3

# %%
agent = DRLAgent(env = env_train)
TD3_PARAMS = {"batch_size": 100, 
              "buffer_size": 1000000, 
              "learning_rate": 0.001}

model_td3 = agent.get_model("td3",model_kwargs = TD3_PARAMS)
# Out:
# {'batch_size': 100, 'buffer_size': 1000000, 'learning_rate': 0.001}
# Using cpu device

# %%
trained_td3 = agent.train_model(model=model_td3, 
                             tb_log_name='td3',
                             total_timesteps=30000)
# Out:
# day: 2892, episode: 60
# begin_total_asset: 1000000.00
# end_total_asset: 4178020.38
# total_reward: 3178020.38
# total_cost: 1315.25
# total_trades: 43424
# Sharpe: 0.820
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 35        |
# |    time_elapsed    | 321       |
# |    total_timesteps | 11572     |
# | train/             |           |
# |    actor_loss      | 69.7      |
# |    critic_loss     | 1.47e+03  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 8679      |
# |    reward          | 4.1390066 |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 33        |
# |    time_elapsed    | 700       |
# |    total_timesteps | 23144     |
# | train/             |           |
# |    actor_loss      | 41.4      |
# |    critic_loss     | 265       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 20251     |
# |    reward          | 4.1390066 |
# ----------------------------------

# %% [markdown]
# ### Agent 5: SAC

# %%
agent = DRLAgent(env = env_train)
SAC_PARAMS = {
    "batch_size": 128,
    "buffer_size": 1000000,
    "learning_rate": 0.0001,
    "learning_starts": 100,
    "ent_coef": "auto_0.1",
}

model_sac = agent.get_model("sac",model_kwargs = SAC_PARAMS)
# Out:
# {'batch_size': 128, 'buffer_size': 1000000, 'learning_rate': 0.0001, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cpu device

# %%
trained_sac = agent.train_model(model=model_sac, 
                             tb_log_name='sac',
                             total_timesteps=60000)
# Out:
# day: 2892, episode: 70
# begin_total_asset: 1000000.00
# end_total_asset: 5621357.33
# total_reward: 4621357.33
# total_cost: 152371.87
# total_trades: 55828
# Sharpe: 0.874
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 27        |
# |    time_elapsed    | 427       |
# |    total_timesteps | 11572     |
# | train/             |           |
# |    actor_loss      | 643       |
# |    critic_loss     | 95        |
# |    ent_coef        | 0.137     |
# |    ent_coef_loss   | -93.7     |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 11471     |
# |    reward          | 5.6995516 |
# ----------------------------------
# -----------------------------------
# | time/              |            |
# |    episodes        | 8          |
# |    fps             | 26         |
# |    time_elapsed    | 858        |
# |    total_timesteps | 23144      |
# | train/             |            |
# |    actor_loss      | 310        |
# |    critic_loss     | 36.4       |
# |    ent_coef        | 0.0438     |
# |    ent_coef_loss   | -127       |
# |    learning_rate   | 0.0001     |
# |    n_updates       | 23043      |
# |    reward          | -3.1947215 |
# -----------------------------------
# day: 2892, episode: 80
# begin_total_asset: 1000000.00
# end_total_asset: 3824814.37
# total_reward: 2824814.37
# total_cost: 4333.98
# total_trades: 46777
# Sharpe: 0.649
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 26       |
# |    time_elapsed    | 1294     |
# |    total_timesteps | 34716    |
# | train/             |          |
# |    actor_loss      | 144      |
# |    critic_loss     | 10.6     |
# |    ent_coef        | 0.0141   |
# |    ent_coef_loss   | -133     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 34615    |
# |    reward          | -3.32923 |
# ---------------------------------
# -----------------------------------
# | time/              |            |
# |    episodes        | 16         |
# |    fps             | 26         |
# |    time_elapsed    | 1725       |
# |    total_timesteps | 46288      |
# | train/             |            |
# |    actor_loss      | 86.3       |
# |    critic_loss     | 9.43       |
# |    ent_coef        | 0.00464    |
# |    ent_coef_loss   | -106       |
# |    learning_rate   | 0.0001     |
# |    n_updates       | 46187      |
# |    reward          | 0.09364837 |
# -----------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 26       |
# |    time_elapsed    | 2151     |
# |    total_timesteps | 57860    |
# | train/             |          |
# |    actor_loss      | 54.5     |
# |    critic_loss     | 5.49     |
# |    ent_coef        | 0.00175  |
# |    ent_coef_loss   | -13.1    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 57759    |
# |    reward          | 2.227846 |
# ---------------------------------

# %% [markdown]
# ## In-sample Performance
#
# Assume that the initial capital is $1,000,000.

# %% [markdown]
# ### Set turbulence threshold
# Set the turbulence threshold to be greater than the maximum of insample turbulence data. If current turbulence index is greater than the threshold, then we assume that the current market is volatile

# %%
data_risk_indicator = processed_full[(processed_full.date<'2020-07-01') & (processed_full.date>='2009-01-01')]
insample_risk_indicator = data_risk_indicator.drop_duplicates(subset=['date'])

# %%
insample_risk_indicator.vix.describe()
# Out:
# count    2893.000000
# mean       18.824245
# std         8.489311
# min         9.140000
# 25%        13.330000
# 50%        16.139999
# 75%        21.309999
# max        82.690002
# Name: vix, dtype: float64

# %%
insample_risk_indicator.vix.quantile(0.996)
# Out:
# 57.40400183105453

# %%
insample_risk_indicator.turbulence.describe()
# Out:
# count    2893.000000
# mean       34.574230
# std        43.787152
# min         0.000000
# 25%        14.966103
# 50%        24.124528
# 75%        39.161946
# max       652.504734
# Name: turbulence, dtype: float64

# %%
insample_risk_indicator.turbulence.quantile(0.996)
# Out:
# 276.45335168147477

# %% [markdown]
# ### Trading (Out-of-sample Performance)
#
# We update periodically in order to take full advantage of the data, e.g., retrain quarterly, monthly or weekly. We also tune the parameters along the way, in this notebook we use the in-sample data from 2009-01 to 2020-07 to tune the parameters once, so there is some alpha decay here as the length of trade date extends.
#
# Numerous hyperparameters – e.g. the learning rate, the total number of samples to train on – influence the learning process and are usually determined by testing some variations.

# %%
#trade = data_split(processed_full, '2020-07-01','2021-10-31')
e_trade_gym = StockTradingEnv(df = trade, turbulence_threshold = 70,risk_indicator_col='vix', **env_kwargs)
# env_trade, obs_trade = e_trade_gym.get_sb_env()

# %%
trade.head()
# Out:
#          date   tic        open        high         low       close  \
# 0  2020-07-01  AAPL   91.279999   91.839996   90.977501   89.779884
# 0  2020-07-01  AMGN  235.520004  256.230011  232.580002  238.313583
# 0  2020-07-01   AXP   95.250000   96.959999   93.639999   91.743042
# 0  2020-07-01    BA  185.880005  190.610001  180.039993  180.320007
# 0  2020-07-01   CAT  129.380005  129.399994  125.879997  119.817116
#
#         volume  day      macd     boll_ub     boll_lb     rsi_30      cci_30  \
# 0  110737200.0  2.0  3.010421   92.570729   80.068739  62.807132  107.494001
# 0    6575800.0  2.0  3.608529  230.616477  198.678622  61.279640  271.208771
# 0    3301000.0  2.0 -0.387712  110.012243   87.432131  48.504815  -66.321052
# 0   49036700.0  2.0  5.443193  220.721139  160.932863  50.925771   24.220608
# 0    2807800.0  2.0  1.263827  129.720779  112.569081  52.865423   35.633550
#
#        dx_30  close_30_sma  close_60_sma        vix  turbulence
# 0  29.730532     83.817342     77.609740  28.620001    53.06817
# 0  46.806139    213.212112    214.276892  28.620001    53.06817
# 0   3.142448     96.882071     90.357376  28.620001    53.06817
# 0  15.932920    176.472335    155.614168  28.620001    53.06817
# 0  14.457404    118.586880    112.860600  28.620001    53.06817

# %%
df_account_value, df_actions = DRLAgent.DRL_prediction(
    model=trained_sac, 
    environment = e_trade_gym)
# Out:
# hit end!

# %%
df_account_value.shape
# Out:
# (336, 2)

# %%
df_account_value.tail()
# Out:
#            date  account_value
# 331  2021-10-22   1.288977e+06
# 332  2021-10-25   1.290948e+06
# 333  2021-10-26   1.291105e+06
# 334  2021-10-27   1.283451e+06
# 335  2021-10-28   1.288281e+06

# %%
df_actions.head()
# Out:
#             AAPL  AMGN  AXP  BA  CAT  CRM  CSCO  CVX  DIS  GS  ...  MRK  MSFT  \
# date                                                           ...
# 2020-07-01     0    95    0  95    0   91     0    0   97  97  ...    0    90
# 2020-07-02     0    95    0  95    0   91     0    0   97  97  ...    0    90
# 2020-07-06     0    95    0  95    0   91     0    0   97  97  ...    0    90
# 2020-07-07     0    95    0  95    0   91     0    0   97  97  ...    0    90
# 2020-07-08     0    95    0  95    0   91     0    0   97  97  ...    0    90
#
#             NKE  PG  TRV  UNH   V  VZ  WBA  WMT
# date
# 2020-07-01    0   0    0   72  95   0    0   97
# 2020-07-02    0   0    0   72  95   0    0   97
# 2020-07-06    0   0    0   72  95   0    0   97
# 2020-07-07    0   0    0   72  95   0    0   97
# 2020-07-08    0   0    0   72  95   0    0   97
#
# [5 rows x 29 columns]

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtesting Results
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %% [markdown]
# <a id='6.1'></a>
# ## 7.1 BackTestStats
# pass in df_account_value, this information is stored in env class

# %%
print("==============Get Backtest Results===========")
now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

perf_stats_all = backtest_stats(account_value=df_account_value)
perf_stats_all = pd.DataFrame(perf_stats_all)
perf_stats_all.to_csv("./"+config.RESULTS_DIR+"/perf_stats_all_"+now+'.csv')
# Out:
# ==============Get Backtest Results===========
# Annual return          0.209228
# Cumulative returns     0.288281
# Annual volatility      0.148359
# Sharpe ratio           1.358955
# Calmar ratio           1.694941
# Stability              0.912134
# Max drawdown          -0.123442
# Omega ratio            1.255813
# Sortino ratio          1.963224
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.046908
# Daily value at risk   -0.017891
# dtype: float64
# /home/smith/anaconda3/lib/python3.9/site-packages/pyfolio/timeseries.py:724: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   stats = pd.Series()

# %%
import importlib
import meta
importlib.reload(meta)
from meta.local.yfinance.plot import get_baseline


#baseline stats
print("==============Get Baseline Stats===========")
baseline_df = get_baseline(
        ticker="^DJI", 
        start = df_account_value.loc[0,'date'],
        end = df_account_value.loc[len(df_account_value)-1,'date'],
        proxy="127.0.0.1:1080")

stats = backtest_stats(baseline_df, value_col_name = 'close')
# Out:
# ==============Get Baseline Stats===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (336, 8)
# Annual return          0.269722
# Cumulative returns     0.374922
# Annual volatility      0.139083
# Sharpe ratio           1.792302
# Calmar ratio           3.020136
# Stability              0.919220
# Max drawdown          -0.089308
# Omega ratio            1.347571
# Sortino ratio          2.655481
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.052781
# Daily value at risk   -0.016534
# dtype: float64
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/yahoodownloader.py:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# /home/smith/anaconda3/lib/python3.9/site-packages/pyfolio/timeseries.py:724: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   stats = pd.Series()

# %%
df_account_value.loc[0,'date']
# Out:
# '2020-07-01'

# %%
df_account_value.loc[len(df_account_value)-1,'date']
# Out:
# '2021-10-28'

# %% [markdown]
# <a id='6.2'></a>
# ## 7.2 BackTestPlot

# %%
import importlib
import meta
importlib.reload(meta)
from meta.local.finrl.plot import backtest_plot

print("==============Compare to DJIA===========")
# %matplotlib inline
# S&P 500: ^GSPC
# Dow Jones Index: ^DJI
# NASDAQ 100: ^NDX
backtest_plot(df_account_value, 
             baseline_ticker = '^DJI', 
             baseline_start = df_account_value.loc[0,'date'],
             baseline_end = df_account_value.loc[len(df_account_value)-1,'date'])
# Out:
# ==============Compare to DJIA===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (336, 8)
# /home/smith/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/yahoodownloader.py:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# /home/smith/anaconda3/lib/python3.9/site-packages/pyfolio/timeseries.py:724: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   stats = pd.Series()
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2020-07-01</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2021-10-28</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>16</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>20.923%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>28.828%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>14.836%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>1.36</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>1.69</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.91</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-12.344%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.26</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>1.96</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.05</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-1.789%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>-0.04</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.98</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>12.34</td>
#       <td>2020-09-02</td>
#       <td>2020-10-30</td>
#       <td>2020-12-17</td>
#       <td>77</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4.59</td>
#       <td>2021-08-16</td>
#       <td>2021-09-21</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3.95</td>
#       <td>2020-07-22</td>
#       <td>2020-07-31</td>
#       <td>2020-08-24</td>
#       <td>24</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3.90</td>
#       <td>2021-02-24</td>
#       <td>2021-03-04</td>
#       <td>2021-03-10</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>3.60</td>
#       <td>2021-05-07</td>
#       <td>2021-05-12</td>
#       <td>2021-06-02</td>
#       <td>19</td>
#     </tr>
#   </tbody>
# </table>
# /home/smith/anaconda3/lib/python3.9/site-packages/pyfolio/plotting.py:805: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   oos_cum_returns = pd.Series([])
# /home/smith/anaconda3/lib/python3.9/site-packages/pyfolio/plotting.py:805: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   oos_cum_returns = pd.Series([])
# /home/smith/anaconda3/lib/python3.9/site-packages/pyfolio/plotting.py:805: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   oos_cum_returns = pd.Series([])
# /home/smith/anaconda3/lib/python3.9/site-packages/pyfolio/timeseries.py:541: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   out = pd.Series(index=returns.index)
# /home/smith/anaconda3/lib/python3.9/site-packages/pyfolio/timeseries.py:541: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   out = pd.Series(index=returns.index)
# /home/smith/anaconda3/lib/python3.9/site-packages/pyfolio/timeseries.py:1230: FutureWarning: Indexing a timezone-aware DatetimeIndex with a timezone-naive datetime is deprecated and will raise KeyError in a future version. Use a timezone-aware object instead.
#   period = returns_dupe.loc[start:end]
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>New Normal</th>
#       <td>0.08%</td>
#       <td>-3.75%</td>
#       <td>3.06%</td>
#     </tr>
#   </tbody>
# </table>
# /home/smith/anaconda3/lib/python3.9/site-packages/pyfolio/timeseries.py:1230: FutureWarning: Indexing a timezone-aware DatetimeIndex with a timezone-naive datetime is deprecated and will raise KeyError in a future version. Use a timezone-aware object instead.
#   period = returns_dupe.loc[start:end]
